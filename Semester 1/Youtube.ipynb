# %% [markdown]
# # My question is whether videos with more views have a greater like-to-view ratio.
# # My prediction is that videos with fewer views will have an ~10% greater like-to-view ratio, as these videos tend to be more niche and do well with a limited audience.

# %%
import requests as rq
